# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import pandas as pd
import numpy as np

# %%
# First way to call the 2 group Venn diagram:
venn2(subsets = (10, 5, 2), set_labels = ('Group A', 'Group B')).get_label_by_id('A').set_color('white')
plt.show()

# %% [markdown]
# ### Montipora bleached vs non-bleached

# %%
mont_bvnb_b=pd.read_csv("gitrepos/coral_rnaseq_2017/analyses/montipora/20190611_montipora_all_DEG_b_vs_nb_GO/edgeR.6228.dir/P0.05_C1.bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)
mont_bvnb_nb=pd.read_csv("gitrepos/coral_rnaseq_2017/analyses/montipora/20190611_montipora_all_DEG_b_vs_nb_GO/edgeR.6228.dir/P0.05_C1.non-bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)

# %%
venn2([set(mont_bvnb_b[0]), set(mont_bvnb_nb[0])], ('Bleached', 'Non-bleached'))
plt.show()

# %% [markdown]
# ### Montipora Site 44 vs K4

# %%
mont_44vk4_44=pd.read_csv("gitrepos/coral_rnaseq_2017/analyses/montipora/20191121_montipora_all_DEG_44_vs_k4_GO/edgeR.29831.dir/P0.05_C1.44-UP.subset.GOseq.enriched.GOterms.txt", header=None)
mont_44vk4_k4=pd.read_csv("gitrepos/coral_rnaseq_2017/analyses/montipora/20191121_montipora_all_DEG_44_vs_k4_GO/edgeR.29831.dir/P0.05_C1.k4-UP.subset.GOseq.enriched.GOterms.txt", header=None)

# %%
venn2([set(mont_44vk4_44[0]), set(mont_44vk4_k4[0])], ('Site 44', 'Site K4'))
plt.show()

# %%
bleach_set = set(df0[0])
nonbleach_set = set(df1[0])

# %%
venn2([bleach_set, nonbleach_set], ('Bleached', 'Non-bleached'))
plt.show()
