# %% [markdown]
# ### Import modules

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read in files

# %%
mont_bvnb_b=pd.read_csv("montipora/20190611_montipora_all_DEG_b_vs_nb_GO/edgeR.6228.dir/P0.05_C1.bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)
mont_bvnb_nb=pd.read_csv("montipora/20190611_montipora_all_DEG_b_vs_nb_GO/edgeR.6228.dir/P0.05_C1.non-bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)
mont_44vk4_44=pd.read_csv("montipora/20191121_montipora_all_DEG_44_vs_k4_GO/edgeR.29831.dir/P0.05_C1.44-UP.subset.GOseq.enriched.GOterms.txt", header=None)
mont_44vk4_k4=pd.read_csv("montipora/20191121_montipora_all_DEG_44_vs_k4_GO/edgeR.29831.dir/P0.05_C1.k4-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_bvnb_b=pd.read_csv("porites/20190603_all_salmon_DEG_b_vs_nb_GO/edgeR.32435.dir/P0.05_C1.bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_bvnb_nb=pd.read_csv("porites/20190603_all_salmon_DEG_b_vs_nb_GO/edgeR.32435.dir/P0.05_C1.non-bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fvm_k5_f=pd.read_csv("porites/20190610_all_DEG_f_vs_m_k5_GO/edgeR.8639.dir/P0.05_C1.female-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fvm_k5_m=pd.read_csv("porites/20190610_all_DEG_f_vs_m_k5_GO/edgeR.8639.dir/P0.05_C1.male-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvfnb_k5_b=pd.read_csv("porites/20191206_all_DEG_f.b_vs_f.nb_k5_GO/edgeR.20746.dir/P0.05_C1.bleached-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvfnb_k5_nb=pd.read_csv("porites/20191206_all_DEG_f.b_vs_f.nb_k5_GO/edgeR.20746.dir/P0.05_C1.non-bleached-UP.subset.GOseq.depleted.GOterms.txt", header=None)
porites_44vk5_44=pd.read_csv("porites/20191210_porites_all_DEG_44_vs_k5_GO/edgeR.13791.dir/P0.05_C1.44-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_44vk5_k5=pd.read_csv("porites/20191210_porites_all_DEG_44_vs_k5_GO/edgeR.13791.dir/P0.05_C1.K5-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvmb_fb=pd.read_csv("porites/20191210_porites_DEG_f.b_vs_m.b_GO/edgeR.1982.dir/P0.05_C1.bleached-female-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvmb_mb=pd.read_csv("porites/20191210_porites_DEG_f.b_vs_m.b_GO/edgeR.1982.dir/P0.05_C1.bleached-male-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvfnb_44_b=pd.read_csv("porites/20191219_all_DEG_f.b_vs_f.nb_44_GO/edgeR.24131.dir/P0.05_C1.bleached-female-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvfnb_44_nb=pd.read_csv("porites/20191219_all_DEG_f.b_vs_f.nb_44_GO/edgeR.24131.dir/P0.05_C1.non-bleached-female-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvfnb_b=pd.read_csv("porites/20191219_porites_DEG_f.b_vs.nb_GO/edgeR.18559.dir/P0.05_C1.bleached-female-UP.subset.GOseq.enriched.GOterms.txt", header=None)
porites_fbvfnb_nb=pd.read_csv("porites/20191219_porites_DEG_f.b_vs.nb_GO/edgeR.18559.dir/P0.05_C1.non-bleached-female-UP.subset.GOseq.enriched.GOterms.txt", header=None)

# %%
### Montipora bleached vs non-bleached

# %%
venn2([set(mont_bvnb_b[0]), set(mont_bvnb_nb[0])], ('Bleached', 'Non-bleached'))
plt.title("Montipora: Bleached vs. Non-bleached")
plt.show()

# %% [markdown]
# ### Montipora Site 44 vs K4

# %%
venn2([set(mont_44vk4_44[0]), set(mont_44vk4_k4[0])], ('Site 44', 'Site K4'))
plt.title("Montipora Site 44 vs K4")
plt.show()

# %% [markdown]
# ### Porites Bleached vs. Non-bleached

# %%
venn2([set(porites_bvnb_b[0]), set(porites_bvnb_nb[0])], ('Bleached', 'Non-bleached'))
plt.title("Porites Bleached vs. Non-bleached")
plt.show()

# %% [markdown]
# ### Porites Site 44, Female Only Bleached vs. Non-bleached

# %%
venn2([set(porites_fbvfnb_44_b[0]), set(porites_fbvfnb_44_nb[0])], ('Bleached', 'Non-bleached'))
plt.title("Porites Site 44, Female Only Bleached vs. Non-bleached")
plt.show()

# %% [markdown]
# ### Porites Female Only: Bleached vs. Non-bleached

# %%
venn2([set(porites_fbvfnb_b[0]), set(porites_fbvfnb_nb[0])], ('Bleached', 'Non-bleached'))
plt.title("Porites Female Only: Bleached vs. Non-bleached")
plt.show()

# %% [markdown]
# ### Porites Site K5, Female Only: Bleached vs. Non-bleached

# %%
venn2([set(porites_fbvfnb_k5_b[0]), set(porites_fbvfnb_k5_nb[0])], ('Bleached', 'Non-bleached'))
plt.title("Porites Site K5, Female Only: Bleached vs. Non-bleached")
plt.show()

# %% [markdown]
# ### Porites Bleached: Female vs. Male

# %%
venn2([set(porites_fbvmb_fb[0]), set(porites_fbvmb_mb[0])], ('Female Bleached', 'Male Bleached'))
plt.title("Porites Bleached: Female vs. Male")
plt.show()

# %% [markdown]
# ### Porites Site K5: Female vs. Male

# %%
venn2([set(porites_fvm_k5_f[0]), set(porites_fvm_k5_m[0])], ('Female', 'Male'))
plt.title("Porites Site K5: Female vs. Male")
plt.show()
