# %%
# %%bash
# echo "TODAY'S DATE"
# date
# echo "------------"
# echo ""
# lsb_release -a
# echo ""
# echo "------------"
# echo "HOSTNAME: "
# hostname
# echo ""
# echo "------------"
# echo "Computer Specs:"
# echo ""
# lscpu
# echo ""
# echo "------------"
# echo ""
# echo "Memory Specs"
# echo ""
# free -mh
# Out:
# TODAY'S DATE
# Sun Mar 11 10:19:40 PDT 2018
# ------------
#
# Distributor ID:	Ubuntu
# Description:	Ubuntu 16.04.4 LTS
# Release:	16.04
# Codename:	xenial
#
# ------------
# HOSTNAME:
# jpg-d20
#
# ------------
# Computer Specs:
#
# Architecture:          x86_64
# CPU op-mode(s):        32-bit, 64-bit
# Byte Order:            Little Endian
# CPU(s):                24
# On-line CPU(s) list:   0-23
# Thread(s) per core:    2
# Core(s) per socket:    6
# Socket(s):             2
# NUMA node(s):          2
# Vendor ID:             GenuineIntel
# CPU family:            6
# Model:                 44
# Model name:            Intel(R) Xeon(R) CPU           X5680  @ 3.33GHz
# Stepping:              2
# CPU MHz:               1729.000
# CPU max MHz:           3326.0000
# CPU min MHz:           1596.0000
# BogoMIPS:              6666.90
# Virtualization:        VT-x
# L1d cache:             32K
# L1i cache:             32K
# L2 cache:              256K
# L3 cache:              12288K
# ...

# %% [markdown]
# Print list of files for use in FastQC command

# %%
# %%bash
# for file in /mnt/data/coral_RNAseq_fastq/montipora/*.gz
# do
# printf "%s\n" "$file \\"
# done
# Out:
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# ...

# %%
# %%bash
# for file in /mnt/data/coral_RNAseq_fastq/porites/*.gz
# do
# printf "%s\n" "$file \\"
# done
# Out:
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz \
# ...

# %%
# %%bash
# mkdir /mnt/data/coral_RNAseq_fastq/montipora/20180311_fastqc_trimming
# mkdir /mnt/data/coral_RNAseq_fastq/porites/20180311_fastqc_trimming

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/montipora/20180311_fastqc_trimming/
# time fastqc --threads 18 \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-PrNotRecog-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-PrNotRecog-READ2-Sequences.txt.gz
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# bash: line 2: fastqc: command not found
#
# real	0m0.001s
# user	0m0.000s
# sys	0m0.000s

# %%
# %%bash
# echo $PATH
# Out:
# /home/sam/anaconda3/bin:/home/sam/anaconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin

# %% [markdown]
# Needed to re-source the /etc/environment and the ~.bashrc files, since I hadn't done so since installing FastQC.

# %%
# %%bash
# echo $PATH
# Out:
# /home/sam/anaconda3/bin:/home/sam/anaconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/home/shared/samtools-1.7:/home/shared/bowtie2-2.3.4.1-linux-x86_64:/home/shared/FastQC:/home/shared/jellyfish-2.2.9/bin:/home/shared/salmon_0.9.1/bin::/home/shared/samtools-1.7:/home/shared/TrimGalore-0.4.5:/home/shared/trinityrnaseq-Trinity-v2.6.5:/home/shared/ncbi-blast-2.7.1+/bin

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/montipora/20180311_fastqc_trimming/
# time fastqc --threads 18 \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-PrNotRecog-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-PrNotRecog-READ2-Sequences.txt.gz
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Analysis complete for 4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz
# #
# # A fatal error has been detected by the Java Runtime Environment:
# #
# #  SIGSEGV (0xb) at pc=0x00007ff7257e5009, pid=30689, tid=30726
# #
# # JRE version: OpenJDK Runtime Environment (9.0) (build 9-internal+0-2016-04-14-195246.buildd.src)
# # Java VM: OpenJDK 64-Bit Server VM (9-internal+0-2016-04-14-195246.buildd.src, mixed mode, tiered, compressed oops, g1 gc, linux-amd64)
# # Problematic frame:
# # C  [libjava.so+0x1d009][thread 30720 also had an error]
# [thread 30740 also had an error][thread 30731 also had an error][thread 30737 also had an error][thread 30729 also had an error][thread 30734 also had an error][thread 30849 also had an error]
#
# [thread 30730 also had an error]
#
#
#
#
#   JNU_GetEnv+0x19
# #
# ...

# %% [markdown]
# Uninstalled opendjdk-9.
# Installed openjdk-8.
# Hopefully this will resolve Java issue.

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/montipora/20180311_fastqc_trimming/
# time fastqc --threads 18 \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-PrNotRecog-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-PrNotRecog-READ2-Sequences.txt.gz
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Analysis complete for 4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-PrNotRecog-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L6-PrNotRecog-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz
# ...

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/montipora/20180311_fastqc_trimming/
# time fastqc --threads 18 \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P08-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P08-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P10-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P10-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P11-ACTTGA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P11-ACTTGA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P12-TGACCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P12-TGACCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P13-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P13-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P14-GTGGCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P14-GTGGCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P15-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P15-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-PrNotRecog-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-PrNotRecog-READ2-Sequences.txt.gz
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Analysis complete for 4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz
# ...

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/montipora/20180311_fastqc_trimming/
# time multiqc .
# cd /mnt/data/coral_RNAseq_fastq/porites/20180311_fastqc_trimming/
# time multiqc .
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Searching 53 files..
# Searching 60 files..
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# /home/sam/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# [INFO   ]          fastqc : Found 26 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : multiqc_report.html
# [INFO   ]         multiqc : Data        : multiqc_data
# [INFO   ]         multiqc : MultiQC complete
#
# real	0m26.507s
# user	0m24.616s
# sys	0m0.408s
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [INFO   ]          fastqc : Found 30 reports
# [INFO   ]         multiqc : Compressing plot data
# ...

# %% [markdown]
# Looking through MultiQC report, I noticed that one of the sequencing files wasn't present. Will have to download from sequencing facility website (did this outside of notebook).

# %%
# %%bash
# cp /home/sam/uw_drive/coral_rnaseq_2017/ucr_seq_output/illumina.bioinfo.ucr.edu/illumina_runs/web/ae55dd77f1828d82016e4e2ca1d93c6b70d261f3/4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/

# %%
# %%bash
# for file in /mnt/data/coral_RNAseq_fastq/porites/*.gz
# do
# printf "%s\n" "$file \\"
# done
# Out:
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# ...

# %% [markdown]
# Re-run FastQC to include P04 READ2

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/porites/20180311_fastqc_trimming/
# rm -rf *
# time fastqc --threads 18 \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P08-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P08-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P10-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P10-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P11-ACTTGA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P11-ACTTGA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P12-TGACCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P12-TGACCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P13-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P13-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P14-GTGGCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P14-GTGGCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P15-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-P15-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-PrNotRecog-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/porites/4R041-L7-PrNotRecog-READ2-Sequences.txt.gz
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Analysis complete for 4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz
# Analysis complete for 4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz
# Analysis complete for 4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz
# ...

# %%
# %bash
cd /mnt/data/coral_RNAseq_fastq/porites/20180311_fastqc_trimming/
multiqc .
# Out:
#   File "<ipython-input-7-95a49a1a99b6>", line 2
#     cd /mnt/data/coral_RNAseq_fastq/porites/20180311_fastqc_trimming/
#                                                     ^
# SyntaxError: invalid token

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_fastq/porites/20180311_fastqc_trimming/
# multiqc .
# Out:
# Searching 0 files..
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [WARNING]         multiqc : No analysis results found. Cleaning up..
# [INFO   ]         multiqc : MultiQC complete

# %%
# %bash

mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed
mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc

time \
/home/shared/TrimGalore-0.4.5/trim_galore \
--paired \
--output_dir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed \
--fastqc_args \
"--outdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc \
--threads 24" \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
/mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
2> /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/stderr.log

cd /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
/home/sam/anaconda3/bin/multiqc .

cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
#   File "<ipython-input-1-2fc8b198c8e3>", line 3
#     mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed
#                                                         ^
# SyntaxError: invalid token

# %%
# %%bash
#
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --output_dir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Searching 0 files..
# real	0m1.045s
# user	0m0.036s
# sys	0m0.004s
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [WARNING]         multiqc : No analysis results found. Cleaning up..
# [INFO   ]         multiqc : MultiQC complete

# %%
# %%bash
#
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --output_dir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_fastq/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# 1.16
# Searching 0 files..
# mkdir: cannot create directory ‘/mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed’: File exists
# mkdir: cannot create directory ‘/mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc’: File exists
#
# real	0m1.227s
# user	0m0.184s
# sys	0m0.032s
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [WARNING]         multiqc : No analysis results found. Cleaning up..
# [INFO   ]         multiqc : MultiQC complete

# %%
# %%bash
#
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --output_dir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# 1.16
# Analysis complete for 4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz_val_2.fq.gz
# ...

# %%
# %%bash
#
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --output_dir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P08-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P08-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P10-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P10-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P11-ACTTGA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P11-ACTTGA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P12-TGACCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P12-TGACCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P13-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P13-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P14-GTGGCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P14-GTGGCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P15-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P15-GTTTCG-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Searching 17 files..
# mkdir: cannot create directory ‘/mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed’: No such file or directory
# mkdir: cannot create directory ‘/mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc’: No such file or directory
# bash: line 7: /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/stderr.log: No such file or directory
#
# real	0m0.001s
# user	0m0.000s
# sys	0m0.000s
# bash: line 43: cd: /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc: No such file or directory
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [WARNING]         multiqc : No analysis results found. Cleaning up..
# [INFO   ]         multiqc : MultiQC complete

# %%
# %%bash
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --output_dir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P08-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P08-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P10-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P10-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P11-ACTTGA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P11-ACTTGA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P12-TGACCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P12-TGACCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P13-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P13-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P14-GTGGCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P14-GTGGCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P15-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P15-GTTTCG-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Searching 0 files..
# real	0m1.042s
# user	0m0.036s
# sys	0m0.004s
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [WARNING]         multiqc : No analysis results found. Cleaning up..
# [INFO   ]         multiqc : MultiQC complete

# %%
# %%bash
#
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180415_trimmed
# mkdir /mnt/data/coral_RNAseq_2017/montipora/20180415_trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --clip_r1 15 \
# --clip_r2 15 \
# --three_prime_clip_R1 4 \
# --three_prime_clip_R2 4 \
# --output_dir /mnt/data/coral_RNAseq_2017/montipora/20180415_trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/montipora/20180415_trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P07-ATGTCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P07-ATGTCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P08-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P08-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P09-GGCTAC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P09-GGCTAC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P10-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P10-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P11-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P11-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P12-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/montipora/4R041-L6-P12-GCCAAT-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/montipora/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# 1.16
# Analysis complete for 4R041-L6-P01-AGTCAA-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P01-AGTCAA-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P02-CTTGTA-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P02-CTTGTA-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P03-GTTTCG-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P03-GTTTCG-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P04-ATCACG-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P05-TAGCTT-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P05-TAGCTT-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L6-P06-AGTTCC-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L6-P06-AGTTCC-READ2-Sequences.txt.gz_val_2.fq.gz
# ...

# %%
# %%bash
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180415_trimmed
# mkdir /mnt/data/coral_RNAseq_2017/porites/20180415_trimmed/fastqc
#
# time \
# /home/shared/TrimGalore-0.4.5/trim_galore \
# --paired \
# --clip_r1 15 \
# --clip_r2 15 \
# --three_prime_clip_R1 4 \
# --three_prime_clip_R2 4 \
# --output_dir /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed \
# --fastqc_args \
# "--outdir /mnt/data/coral_RNAseq_2017/porites/20180415_trimmed/fastqc \
# --threads 24" \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P08-CTTGTA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P08-CTTGTA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P10-TAGCTT-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P10-TAGCTT-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P11-ACTTGA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P11-ACTTGA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P12-TGACCA-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P12-TGACCA-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P13-ATCACG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P13-ATCACG-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P14-GTGGCC-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P14-GTGGCC-READ2-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P15-GTTTCG-READ1-Sequences.txt.gz \
# /mnt/data/coral_RNAseq_2017/porites/4R041-L7-P15-GTTTCG-READ2-Sequences.txt.gz \
# 2> /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/stderr.log
#
# cd /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# 1.16
# Analysis complete for 4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz_val_2.fq.gz
# Analysis complete for 4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz_val_1.fq.gz
# Analysis complete for 4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz_val_2.fq.gz
# ...

# %%
# %%bash
# cd /mnt/data/coral_RNAseq_2017/montipora/20180415_trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
# /mnt/data/coral_RNAseq_2017/porites/20180415_trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
#
#
# cat ~/.default_subject.mail| msmtp "$EMAIL"
# Out:
# Searching 48 files..
# Searching 49 files..
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [INFO   ]          fastqc : Found 24 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : multiqc_report.html
# [INFO   ]         multiqc : Data        : multiqc_data
# [INFO   ]         multiqc : MultiQC complete
# bash: line 4: /mnt/data/coral_RNAseq_2017/porites/20180415_trimmed/fastqc: Is a directory
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [INFO   ]          fastqc : Found 24 reports
# [INFO   ]         multiqc : Compressing plot data
# ...

# %%
# %%bash
#
# cd /mnt/data/coral_RNAseq_2017/porites/20180415_trimmed/fastqc
# /home/sam/anaconda3/bin/multiqc .
# Out:
# Searching 60 files..
# [WARNING]         multiqc : MultiQC Version v1.5 now available!
# [INFO   ]         multiqc : This is MultiQC v1.4
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# [INFO   ]          fastqc : Found 30 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : multiqc_report.html
# [INFO   ]         multiqc : Data        : multiqc_data
# [INFO   ]         multiqc : MultiQC complete
