# %%
# %%bash
# echo "TODAY'S DATE"
# date
# echo "------------"
# echo ""
# lsb_release -a
# echo ""
# echo "------------"
# echo "HOSTNAME: "
# hostname
# echo ""
# echo "------------"
# echo "Computer Specs:"
# echo ""
# lscpu
# echo ""
# echo "------------"
# echo ""
# echo "Memory Specs"
# echo ""
# free -mh
# Out:
# TODAY'S DATE
# Wed Aug  8 08:15:52 PDT 2018
# ------------
#
# Distributor ID:	Ubuntu
# Description:	Ubuntu 16.04.4 LTS
# Release:	16.04
# Codename:	xenial
#
# ------------
# HOSTNAME:
# jpg-d20
#
# ------------
# Computer Specs:
#
# Architecture:          x86_64
# CPU op-mode(s):        32-bit, 64-bit
# Byte Order:            Little Endian
# CPU(s):                24
# On-line CPU(s) list:   0-23
# Thread(s) per core:    2
# Core(s) per socket:    6
# Socket(s):             2
# NUMA node(s):          2
# Vendor ID:             GenuineIntel
# CPU family:            6
# Model:                 44
# Model name:            Intel(R) Xeon(R) CPU           X5680  @ 3.33GHz
# Stepping:              2
# CPU MHz:               1596.000
# CPU max MHz:           3326.0000
# CPU min MHz:           1596.0000
# BogoMIPS:              6666.89
# Virtualization:        VT-x
# L1d cache:             32K
# L1i cache:             32K
# L2 cache:              256K
# L3 cache:              12288K
# ...

# %%
# %%bash
# source /etc/environment
# echo $PATH
# mkdir /media/sam/4TB_toshiba/porites/20180808_rsem
# cd /mnt/data/coral_RNAseq_2017/porites/20180311_fastqc_trimming/trimmed
# time  /home/shared/Trinityrnaseq-v2.6.6/util/align_and_estimate_abundance.pl \
# --output_dir /media/sam/4TB_toshiba/porites/20180808_rsem \
# --transcripts /media/sam/4TB_toshiba/porites/20180419_trinity/Trinity.fasta \
# --seqType fq \
# --SS_lib_type RF \
# --est_method RSEM \
# --aln_method bowtie2 \
# --trinity_mode \
# --prep_reference \
# --thread_count 23 \
# --left \
# 4R041-L7-P01-AGTTCC-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P02-ACAGTG-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P03-ACTGAT-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P04-GTCCGC-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P05-GAGTGG-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P06-GCCAAT-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P07-AGTCAA-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P08-CTTGTA-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P09-GTGAAA-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P10-TAGCTT-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P11-ACTTGA-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P12-TGACCA-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P13-ATCACG-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P14-GTGGCC-READ1-Sequences.txt.gz_val_1.fq.gz,\
# 4R041-L7-P15-GTTTCG-READ1-Sequences.txt.gz_val_1.fq.gz \
# --right \
# 4R041-L7-P01-AGTTCC-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P02-ACAGTG-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P03-ACTGAT-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P04-GTCCGC-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P05-GAGTGG-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P06-GCCAAT-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P07-AGTCAA-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P08-CTTGTA-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P09-GTGAAA-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P10-TAGCTT-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P11-ACTTGA-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P12-TGACCA-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P13-ATCACG-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P14-GTGGCC-READ2-Sequences.txt.gz_val_2.fq.gz,\
# 4R041-L7-P15-GTTTCG-READ2-Sequences.txt.gz_val_2.fq.gz \
# 1> /media/sam/4TB_toshiba/porites/20180808_rsem/20180808_rsem.out \
# 2> /media/sam/4TB_toshiba/porites/20180808_rsem/20180808_rsem.err
# sed '/^Subject:/ s/ / porites_rsem JOB COMPLETE/' ~/.default-subject.mail | msmtp "$EMAIL"
